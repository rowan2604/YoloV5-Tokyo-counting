# %%
import sys
#sys.path.append(r"C:\Users\romai\anaconda3\envs\computervision\Lib\site-packages")
import cv2
import torch
import numpy as np
import argparse
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
from pathlib import Path as Path

from models.experimental import attempt_load
from utils.datasets import LoadStreams, LoadImages
from utils.general import check_img_size, check_requirements, check_imshow, non_max_suppression, apply_classifier, \
    scale_coords, xyxy2xywh, strip_optimizer, set_logging, increment_path
from utils.plots import plot_one_box
from utils.torch_utils import select_device, load_classifier, time_synchronized, TracedModel
# Out:
# Using cache found in C:\Users\romai/.cache\torch\hub\ultralytics_yolov5_master
# requirements: YOLOv5 requirements "gitpython" "torchvision>=0.8.1" not found, attempting AutoUpdate...
# Requirement already satisfied: gitpython in c:\users\romai\anaconda3\envs\computervision\lib\site-packages (3.1.30)
# Requirement already satisfied: torchvision>=0.8.1 in c:\users\romai\anaconda3\envs\computervision\lib\site-packages (0.14.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\romai\anaconda3\envs\computervision\lib\site-packages (from gitpython) (4.0.10)
# Requirement already satisfied: typing_extensions in c:\users\romai\anaconda3\envs\computervision\lib\site-packages (from torchvision>=0.8.1) (4.4.0)
# Requirement already satisfied: numpy in c:\users\romai\anaconda3\envs\computervision\lib\site-packages (from torchvision>=0.8.1) (1.23.5)
# Requirement already satisfied: requests in c:\users\romai\anaconda3\envs\computervision\lib\site-packages (from torchvision>=0.8.1) (2.28.1)
# Requirement already satisfied: torch==1.13.1 in c:\users\romai\anaconda3\envs\computervision\lib\site-packages (from torchvision>=0.8.1) (1.13.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\romai\anaconda3\envs\computervision\lib\site-packages (from torchvision>=0.8.1) (9.3.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\romai\anaconda3\envs\computervision\lib\site-packages (from gitdb<5,>=4.0.1->gitpython) (5.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\romai\anaconda3\envs\computervision\lib\site-packages (from requests->torchvision>=0.8.1) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\romai\anaconda3\envs\computervision\lib\site-packages (from requests->torchvision>=0.8.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\romai\anaconda3\envs\computervision\lib\site-packages (from requests->torchvision>=0.8.1) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\romai\anaconda3\envs\computervision\lib\site-packages (from requests->torchvision>=0.8.1) (1.26.14)
#
# requirements: 2 packages updated per C:\Users\romai\.cache\torch\hub\ultralytics_yolov5_master\requirements.txt
# requirements:  Restart runtime or rerun command for updates to take effect
#
# YOLOv5  2023-2-7 Python-3.9.12 torch-1.13.0+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [41], in <cell line: 11>()
#       8 from pathlib import Path as Path
#      10 from models.experimental import attempt_load
# ---> 11 from utils.datasets import LoadStreams, LoadImages
#      12 from utils.general import check_img_size, check_requirements, check_imshow, non_max_suppression, apply_classifier, \
#      13     scale_coords, xyxy2xywh, strip_optimizer, set_logging, increment_path
#      14 from utils.plots import plot_one_box
#
# ModuleNotFoundError: No module named 'utils.datasets'

# %%
parser = argparse.ArgumentParser()
parser.add_argument('--conf-thres', type=float, default=0.25, help='object confidence threshold')
parser.add_argument('--iou-thres', type=float, default=0.45, help='IOU threshold for NMS')
parser.add_argument('--device', default='', help='cuda device, i.e. 0 or 0,1,2,3 or cpu')
parser.add_argument('--view-img', action='store_true', help='display results')
parser.add_argument('--save-txt', action='store_true', help='save results to *.txt')
parser.add_argument('--save-conf', action='store_true', help='save confidences in --save-txt labels')
parser.add_argument('--nosave', action='store_true', help='do not save images/videos')
parser.add_argument('--classes', nargs='+', type=int, help='filter by class: --class 0, or --class 0 2 3')
parser.add_argument('--agnostic-nms', action='store_true', help='class-agnostic NMS')
parser.add_argument('--augment', action='store_true', help='augmented inference')
parser.add_argument('--update', action='store_true', help='update all models')
parser.add_argument('--project', default='runs/detect', help='save results to project/name')
parser.add_argument('--name', default='exp', help='save results to project/name')
parser.add_argument('--exist-ok', action='store_true', help='existing project/name ok, do not increment')
parser.add_argument('--no-trace', action='store_true', help='don`t trace model')
opt = parser.parse_args()
# Out:
# usage: ipykernel_launcher.py [-h] [--conf-thres CONF_THRES] [--iou-thres IOU_THRES] [--device DEVICE] [--view-img]
#                              [--save-txt] [--save-conf] [--nosave] [--classes CLASSES [CLASSES ...]] [--agnostic-nms]
#                              [--augment] [--update] [--project PROJECT] [--name NAME] [--exist-ok] [--no-trace]
# ipykernel_launcher.py: error: unrecognized arguments: -f C:\Users\romai\AppData\Roaming\jupyter\runtime\kernel-9e51d332-9a3e-4620-a918-304cfd376ee7.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
def detect(source,weights, save_img=True,conf = 0.25,imgsz =640):
    save_img = not True and not source.endswith('.txt')  # save inference images
    webcam = source.isnumeric() or source.endswith('.txt') or source.lower().startswith(
        ('rtsp://', 'rtmp://', 'http://', 'https://'))

    # Directories
    save_dir = Path(increment_path(Path('runs/detect') / 'exp', exist_ok=True))  # pas forcement
    (save_dir / 'labels' if save_txt else save_dir).mkdir(parents=True, exist_ok=True)  # make dir

    # Initialize
    set_logging()
    device = select_device('')
    half = device.type != 'cpu'  # half precision only supported on CUDA

    # Load model
    model = attempt_load(weights, map_location=device)  # load FP32 model
    stride = int(model.stride.max())  # model stride
    imgsz = check_img_size(imgsz, s=stride)  # check img_size

    if trace:
        model = TracedModel(model, device, imgsz)

    if half:
        model.half()  # to FP16

    # Second-stage classifier
    classify = False
    if classify:
        modelc = load_classifier(name='resnet101', n=2)  # initialize
        modelc.load_state_dict(torch.load('weights/resnet101.pt', map_location=device)['model']).to(device).eval()

    # Set Dataloader
    vid_path, vid_writer = None, None
    if webcam:
        view_img = check_imshow()
        cudnn.benchmark = True  # set True to speed up constant image size inference
        dataset = LoadStreams(source, img_size=imgsz, stride=stride)
    else:
        dataset = LoadImages(source, img_size=imgsz, stride=stride)

    # Get names and colors
    names = model.module.names if hasattr(model, 'module') else model.names
    colors = [[random.randint(0, 255) for _ in range(3)] for _ in names]

    # Run inference
    if device.type != 'cpu':
        model(torch.zeros(1, 3, imgsz, imgsz).to(device).type_as(next(model.parameters())))  # run once
    old_img_w = old_img_h = imgsz
    old_img_b = 1

    t0 = time.time()
    for path, img, im0s, vid_cap in dataset:
        img = torch.from_numpy(img).to(device)
        img = img.half() if half else img.float()  # uint8 to fp16/32
        img /= 255.0  # 0 - 255 to 0.0 - 1.0
        if img.ndimension() == 3:
            img = img.unsqueeze(0)

        # Warmup
        if device.type != 'cpu' and (old_img_b != img.shape[0] or old_img_h != img.shape[2] or old_img_w != img.shape[3]):
            old_img_b = img.shape[0]
            old_img_h = img.shape[2]
            old_img_w = img.shape[3]
            for i in range(3):
                model(img, augment=True)[0]

        # Inference
        t1 = time_synchronized()
        with torch.no_grad():   # Calculating gradients would cause a GPU memory leak
            pred = model(img, augment=True)[0]
        t2 = time_synchronized()

        # Apply NMS
        pred = non_max_suppression(pred, 0.25, 0.45, classes=0, agnostic=True)
        t3 = time_synchronized()

        # Apply Classifier
        if classify:
            pred = apply_classifier(pred, modelc, img, im0s)

        # Process detections
        for i, det in enumerate(pred):  # detections per image
            if webcam:  # batch_size >= 1
                p, s, im0, frame = path[i], '%g: ' % i, im0s[i].copy(), dataset.count
            else:
                p, s, im0, frame = path, '', im0s, getattr(dataset, 'frame', 0)

            p = Path(p)  # to Path
            save_path = str(save_dir / p.name)  # img.jpg
            txt_path = str(save_dir / 'labels' / p.stem) + ('' if dataset.mode == 'image' else f'_{frame}')  # img.txt
            gn = torch.tensor(im0.shape)[[1, 0, 1, 0]]  # normalization gain whwh
            if len(det):
                # Rescale boxes from img_size to im0 size
                det[:, :4] = scale_coords(img.shape[2:], det[:, :4], im0.shape).round()

                # Print results
                for c in det[:, -1].unique():
                    n = (det[:, -1] == c).sum()  # detections per class
                    s += f"{n} {names[int(c)]}{'s' * (n > 1)}, "  # add to string

                # Write results
                for *xyxy, conf, cls in reversed(det):
                    if save_txt:  # Write to file
                        xywh = (xyxy2xywh(torch.tensor(xyxy).view(1, 4)) / gn).view(-1).tolist()  # normalized xywh
                        line = (cls, *xywh, conf) if True else (cls, *xywh)  # label format
                        with open(txt_path + '.txt', 'a') as f:
                            f.write(('%g ' * len(line)).rstrip() % line + '\n')

                    if save_img or view_img:  # Add bbox to image
                        label = f'{names[int(cls)]} {conf:.2f}'
                        plot_one_box(xyxy, im0, label=label, color=colors[int(cls)], line_thickness=1)

            # Print time (inference + NMS)
            print(f'{s}Done. ({(1E3 * (t2 - t1)):.1f}ms) Inference, ({(1E3 * (t3 - t2)):.1f}ms) NMS')

            # Stream results
            if view_img:
                cv2.imshow(str(p), im0)
                cv2.waitKey(1)  # 1 millisecond

            # Save results (image with detections)
            if save_img:
                if dataset.mode == 'image':
                    cv2.imwrite(save_path, im0)
                    print(f" The image with the result is saved in: {save_path}")
                else:  # 'video' or 'stream'
                    if vid_path != save_path:  # new video
                        vid_path = save_path
                        if isinstance(vid_writer, cv2.VideoWriter):
                            vid_writer.release()  # release previous video writer
                        if vid_cap:  # video
                            fps = vid_cap.get(cv2.CAP_PROP_FPS)
                            w = int(vid_cap.get(cv2.CAP_PROP_FRAME_WIDTH))
                            h = int(vid_cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
                        else:  # stream
                            fps, w, h = 30, im0.shape[1], im0.shape[0]
                            save_path += '.mp4'
                        vid_writer = cv2.VideoWriter(save_path, cv2.VideoWriter_fourcc(*'mp4v'), fps, (w, h))
                    vid_writer.write(im0)

    if save_txt or save_img:
        s = f"\n{len(list(save_dir.glob('labels/*.txt')))} labels saved to {save_dir / 'labels'}" if save_txt else ''
        #print(f"Results saved to {save_dir}{s}")

    print(f'Done. ({time.time() - t0:.3f}s)')

# %%
detect("tokyo-night-view.mp4","yolov5s.pt" )
#detect.py --weights yolov7.pt --conf 0.25 --img-size 640 --source football1.mp4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 detect("tokyo-night-view.mp4","yolov5s.pt" )
#
# Input In [39], in detect(source, weights, save_img, conf, imgsz)
#       3 webcam = source.isnumeric() or source.endswith('.txt') or source.lower().startswith(
#       4     ('rtsp://', 'rtmp://', 'http://', 'https://'))
#       6 # Directories
# ----> 7 save_dir = Path(increment_path(Path('runs/detect') / 'exp', exist_ok=True))  # pas forcement
#       8 (save_dir / 'labels' if save_txt else save_dir).mkdir(parents=True, exist_ok=True)  # make dir
#      10 # Initialize
#
# NameError: name 'increment_path' is not defined
